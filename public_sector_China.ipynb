# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
publ_sect = pd.read_excel("C:/Users/m218101/Desktop/WBS_Coding_school/Course/Final_project/BRICS_World_Bank_Indicators/BRICS_Public_Sector_and_Society_Data.xlsx")

# %%
top10depart_China_1995_2018 = pd.read_csv("C:/Users/m218101/Desktop/WBS_Coding_school/Course/Final_project/intern_tourism_demographics/top10depart_China_1995_2018.csv")

# %%
top10depart_China_1995_2018 = top10depart_China_1995_2018.set_index('Unnamed: 0')

# %%
top10depart_China_1995_2018.index.names = [None]

# %%
top10depart_China_1995_2018
# Out:
#   Country_Name  Series_Name       1995       1996       1997       1998  \
# 3        China          NaN  4520000.0  5061000.0  5324000.0  8426000.0
#
#         1999        2000        2001        2002        2003        2004  \
# 3  9232000.0  10473000.0  12133000.0  16602000.0  20222000.0  28853000.0
#
#          2005        2006        2007        2008        2009        2010  \
# 3  31026000.0  34524000.0  40954000.0  45844000.0  47656000.0  57386000.0
#
#          2011        2012        2013         2014         2015         2016  \
# 3  70250000.0  83182000.0  98185000.0  116593000.0  127860000.0  135130000.0
#
#           2017         2018  2019  2020
# 3  143035000.0  149720000.0   NaN   NaN

# %%
publ_sect.head(2)
# Out:
#   Country Name Country Code  \
# 0       Brazil          BRA
# 1       Brazil          BRA
#
#                                          Series Name  \
# 0  Adequacy of social insurance programs (% of to...
# 1  Adequacy of social protection and labor progra...
#
#                 Series Code  1970 [YR1970]  1971 [YR1971]  1972 [YR1972]  \
# 0  per_si_allsi.adq_pop_tot            NaN            NaN            NaN
# 1     per_allsp.adq_pop_tot            NaN            NaN            NaN
#
#    1973 [YR1973]  1974 [YR1974]  1975 [YR1975]  1976 [YR1976]  1977 [YR1977]  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
#
#    1978 [YR1978]  1979 [YR1979]  1980 [YR1980]  1981 [YR1981]  1982 [YR1982]  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
#
# ...

# %%
pb_s = publ_sect.copy()

# %%
pb_s = pb_s.rename(columns={"Country Name": "Country_Name","Country Code": "Country_Code", "Series Name": "Series_Name", "Series Code": "Series_Code"})

# %%
pb_s.Series_Name.unique()
# Out:
# array(['Adequacy of social insurance programs (% of total welfare of beneficiary households)',
#        'Adequacy of social protection and labor programs (% of total welfare of beneficiary households)',
#        'Adequacy of social safety net programs (% of total welfare of beneficiary households)',
#        'Adequacy of unemployment benefits and ALMP (% of total welfare of beneficiary households)',
#        'Air transport, freight (million ton-km)',
#        'Air transport, passengers carried',
#        'Air transport, registered carrier departures worldwide',
#        'Annualized average growth rate in per capita real survey mean consumption or income, bottom 40% of population (%)',
#        'Annualized average growth rate in per capita real survey mean consumption or income, total population (%)',
#        'Armed forces personnel (% of total labor force)',
#        'Armed forces personnel, total',
#        'Arms exports (SIPRI trend indicator values)',
# ...

# %%
pb_s.columns = pb_s.columns.str.replace(' \[YR\d+\]', '', regex=True)

# %%
pb_s_china = pb_s.loc[pb_s["Country_Name"] == "China", :]

# %%
pb_s_china_1995_2018 = pb_s_china.drop(pb_s_china.loc[:,'1970':'1994'].columns, axis=1)

# %%
pb_s_china_1995_2018=pb_s_china_1995_2018.drop(['Country_Code','Series_Code'], axis=1)

# %%
result = pd.concat([top10depart_China_1995_2018, pb_s_china_1995_2018], axis=0)

# %%
result.head(3)
# Out:
#     Country_Name                                        Series_Name  \
# 3          China                                                NaN
# 319        China  Adequacy of social insurance programs (% of to...
# 320        China  Adequacy of social protection and labor progra...
#
#           1995       1996       1997       1998       1999        2000  \
# 3    4520000.0  5061000.0  5324000.0  8426000.0  9232000.0  10473000.0
# 319        NaN        NaN        NaN        NaN        NaN         NaN
# 320        NaN        NaN        NaN        NaN        NaN         NaN
#
#            2001        2002        2003        2004        2005        2006  \
# 3    12133000.0  16602000.0  20222000.0  28853000.0  31026000.0  34524000.0
# 319         NaN         NaN         NaN         NaN         NaN         NaN
# 320         NaN         NaN         NaN         NaN         NaN         NaN
#
#            2007        2008        2009        2010        2011        2012  \
# ...

# %%
result_melt = result.melt(id_vars=['Country_Name','Series_Name'], value_vars=['1995','1996','1997','1998','1999','2000','2001'
                                                                              ,'2002','2003','2004','2005','2006','2007','2008'
                                                                              ,'2009','2010','2011','2012','2013','2014','2015'
                                                                              ,'2016','2017','2018','2019','2020'], ignore_index=False) #or transpose

# %%
result_melt
# Out:
#     Country_Name                                        Series_Name variable  \
# 3          China                                                NaN     1995
# 319        China  Adequacy of social insurance programs (% of to...     1995
# 320        China  Adequacy of social protection and labor progra...     1995
# 321        China  Adequacy of social safety net programs (% of t...     1995
# 322        China  Adequacy of unemployment benefits and ALMP (% ...     1995
# 323        China            Air transport, freight (million ton-km)     1995
# 324        China                  Air transport, passengers carried     1995
# 325        China  Air transport, registered carrier departures w...     1995
# 326        China  Annualized average growth rate in per capita r...     1995
# 327        China  Annualized average growth rate in per capita r...     1995
# 328        China    Armed forces personnel (% of total labor force)     1995
# ...

# %%
result_transpose = result.T

# %%
result_transpose.head(5)
# Out:
#                     3                                                  319  \
# Country_Name      China                                              China
# Series_Name         NaN  Adequacy of social insurance programs (% of to...
# 1995          4520000.0                                                NaN
# 1996          5061000.0                                                NaN
# 1997          5324000.0                                                NaN
#
#                                                             320  \
# Country_Name                                              China
# Series_Name   Adequacy of social protection and labor progra...
# 1995                                                        NaN
# 1996                                                        NaN
# 1997                                                        NaN
#
#                                                             321  \
# ...

# %%
df=result_transpose.copy()

# %%
df.columns = df.columns.astype(str)

# %%
df = df.rename(columns={'3': 'dep3'})

# %%
df = df.drop(['Country_Name','Series_Name','2020'])

# %%
df = df.fillna(method='bfill')
df = df.fillna(method='ffill')

# %%
df.corrwith(df["dep3"],axis=0).sort_values()
# Out:
# 423    -0.976869
# 422    -0.975817
# 424    -0.973106
# 559    -0.972337
# 493    -0.952154
# 497    -0.950002
# 495    -0.948989
# 502    -0.946092
# 633    -0.942321
# 634    -0.941695
# 556    -0.940709
# 437    -0.940404
# 375    -0.940096
# 632    -0.939394
# 436    -0.938919
# 580    -0.938538
# 558    -0.938226
# 581    -0.937948
# 417    -0.937276
# 579    -0.935653
# 441    -0.933563
# 377    -0.930543
# 482    -0.929699
# 439    -0.925861
# 598    -0.924621
# 376    -0.918338
# 433    -0.916948
# 505    -0.909734
# 597    -0.905082
# 555    -0.903468
# 522    -0.898350
# 557    -0.888758
# 560    -0.887349
# 435    -0.886330
# 506    -0.880796
# 489    -0.876877
# 328    -0.871941
# 329    -0.869472
# 499    -0.866609
# 539    -0.862986
# 501    -0.853331
# 554    -0.852324
# 540    -0.851824
# 431    -0.850881
# 338    -0.849048
# 507    -0.843564
# 504    -0.832254
# 587    -0.822927
# 486    -0.784344
# 494    -0.564623
# 500    -0.564623
# 496    -0.564623
# ...

# %%
df_ind = df.reset_index()

# %%
df_ind.head(2)
# Out:
#   index       dep3        319        320       321  322          323  \
# 0  1995  4520000.0  55.345345  36.829963  2.337669  NaN  1501.000000
# 1  1996  5061000.0  55.345345  36.829963  2.337669  NaN  1688.599976
#
#           324       325   326   327       328        329           330  \
# 0  47564500.0  397600.0  8.38  7.12  0.602128  4130000.0  1.008000e+09
# 1  51770100.0  493000.0  8.38  7.12  0.592582  4135000.0  7.660000e+08
#
#             331  332  333  334  335  336  337   338       339       340  \
# 0  7.390000e+08  NaN  NaN  NaN  NaN  NaN  NaN  36.0  2.162979  2.998682
# 1  1.528000e+09  NaN  NaN  NaN  NaN  NaN  NaN  36.0  2.162979  2.998682
#
#          341  342  343  344  345  346  347  348  349  350  351  352  353  354  \
# 0  24.242173  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1  24.242173  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#    355  356  357  358  359  360  361  362  363  364  365  366  367  368  369  \
# ...

# %%
#Employment to population ratio, 15+, total
# Out:
#   Input In [82]
#     Employment to population ratio, 15+, total
#                ^
# SyntaxError: invalid syntax

# %%
result_melt.loc[result_melt["Series_Name"].str.contains("Employment to population ratio, 15+, total")]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [85], in <cell line: 1>()
# ----> 1 result_melt.iloc[result_melt["Series_Name"].str.contains("Employment to population ratio, 15+, total")]
#
# File ~\Anaconda3\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\Anaconda3\lib\site-packages\pandas\core\indexing.py:1505, in _iLocIndexer._getitem_axis(self, key, axis)
#    1502 if isinstance(key, list):
#    1503     key = np.asarray(key)
# -> 1505 if com.is_bool_indexer(key):
#    1506     self._validate_key(key, axis)
#    1507     return self._getbool_axis(key, axis=axis)
#
# File ~\Anaconda3\lib\site-packages\pandas\core\common.py:144, in is_bool_indexer(key)
# ...

# %%
result_transpose[[419,524,523,429,428,325,450,374,430,470,324,567,602,607,594,552,610,469,525,447]].iloc[1]
# Out:
# 419    Employers, female (% of female employment) (mo...
# 524                   Military expenditure (current USD)
# 523                   Military expenditure (current LCU)
# 429    Employment in services, female (% of female em...
# 428    Employment in services (% of total employment)...
# 325    Air transport, registered carrier departures w...
# 450        GDP per person employed (constant 2017 PPP $)
# 374    Container port traffic (TEU: 20 foot equivalen...
# 430    Employment in services, male (% of male employ...
# 470               ICT service exports (BoP, current US$)
# 324                    Air transport, passengers carried
# 567    Railways, passengers carried (million passenge...
# 602    Taxes on income, profits and capital gains (cu...
# 607              Trademark applications, direct resident
# 594                            Tax revenue (current LCU)
# 552                       Patent applications, residents
# ...

# %%
melt_to_plot0 = result_melt[result_melt.index.isin([431,433,435])] #223

# %%
melt_to_plot1 = result_melt[result_melt.index.isin([429,428,430])] #223

# %%
melt_to_plot2 = result_melt[result_melt.index.isin([524])] #223

# %%
melt_to_plot3 = result_melt[result_melt.index.isin([374])] #223

# %%
melt_to_plot4 = result_melt[result_melt.index.isin([552])] #223

# %%
melt_to_plot5 = result_melt[result_melt.index.isin([594])] #223

# %%
melt_ind0 = melt_to_plot0.reset_index()

# %%
melt_ind1 = melt_to_plot1.reset_index()

# %%
melt_ind2 = melt_to_plot2.reset_index()

# %%
melt_ind3 = melt_to_plot3.reset_index()

# %%
melt_ind4 = melt_to_plot4.reset_index()

# %%
melt_ind5= melt_to_plot5.reset_index()

# %%
e_ch0 = melt_ind0.pivot(index = 'variable', columns='Series_Name', values='value')
e_ch0.plot(kind='line',figsize=(10,5))
ax = plt.subplot(111)
ax.set_xlabel('Year')
#ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.legend(fontsize=13)
plt.savefig('C:/Users/m218101/Desktop/WBS_Coding_school/Course/Final_project/intern_tourism_demographics/pb_s_china_0.png',dpi=200
           ,bbox_inches='tight') 
e_ch1 = melt_ind1.pivot(index = 'variable', columns='Series_Name', values='value')
e_ch1.plot(kind='line',figsize=(10,5))
ax = plt.subplot(111)
ax.set_xlabel('Year')
#ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.legend(fontsize=13)
plt.savefig('C:/Users/m218101/Desktop/WBS_Coding_school/Course/Final_project/intern_tourism_demographics/pb_s_china_1.png',dpi=200
           ,bbox_inches='tight') 
e_ch2 = melt_ind2.pivot(index = 'variable', columns='Series_Name', values='value')
e_ch2.plot(kind='line',figsize=(10,5))
ax = plt.subplot(111)
ax.set_xlabel('Year')
#ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.legend(fontsize=13)
plt.savefig('C:/Users/m218101/Desktop/WBS_Coding_school/Course/Final_project/intern_tourism_demographics/pb_s_china_2.png',dpi=200
           ,bbox_inches='tight')
e_ch3 = melt_ind3.pivot(index = 'variable', columns='Series_Name', values='value')
e_ch3.plot(kind='line',figsize=(10,5))
ax = plt.subplot(111)
ax.set_xlabel('Year')
#ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.legend(fontsize=13)
plt.savefig('C:/Users/m218101/Desktop/WBS_Coding_school/Course/Final_project/intern_tourism_demographics/pb_s_china_3.png',dpi=200
           ,bbox_inches='tight') 
e_ch4 = melt_ind4.pivot(index = 'variable', columns='Series_Name', values='value')
e_ch4.plot(kind='line',figsize=(10,5))
ax = plt.subplot(111)
ax.set_xlabel('Year')
#ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.legend(fontsize=13)
plt.savefig('C:/Users/m218101/Desktop/WBS_Coding_school/Course/Final_project/intern_tourism_demographics/pb_s_china_4.png',dpi=200
           ,bbox_inches='tight')
e_ch5 = melt_ind5.pivot(index = 'variable', columns='Series_Name', values='value')
e_ch5.plot(kind='line',figsize=(10,5))
ax = plt.subplot(111)
ax.set_xlabel('Year')
#ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.legend(fontsize=13)
plt.savefig('C:/Users/m218101/Desktop/WBS_Coding_school/Course/Final_project/intern_tourism_demographics/pb_s_china_5.png',dpi=200
           ,bbox_inches='tight')

# %%
result_transpose[[423,422,424,559,493,497,495,502,633,634,556,437,375,632,436,580,558,581,417,579]].iloc[1]
# Out:
# 423    Employment in agriculture, female (% of female...
# 422    Employment in agriculture (% of total employme...
# 424    Employment in agriculture, male (% of male emp...
# 559    Poverty headcount ratio at $5.50 a day (2011 P...
# 493    Labor force participation rate for ages 15-24,...
# 497    Labor force participation rate for ages 15-24,...
# 495    Labor force participation rate for ages 15-24,...
# 502    Labor force participation rate, male (% of mal...
# 633    Vulnerable employment, male (% of male employm...
# 634    Vulnerable employment, total (% of total emplo...
# 556            Poverty gap at $5.50 a day (2011 PPP) (%)
# 437    Employment to population ratio, ages 15-24, fe...
# 375    Contributing family workers, female (% of fema...
# 632    Vulnerable employment, female (% of female emp...
# 436    Employment to population ratio, 15+, total (%)...
# 580    Self-employed, male (% of male employment) (mo...
# ...

# %%
melt_neg1 = result_melt[result_melt.index.isin([559,497])] #493,502,495

# %%
melt_plot1 = melt_neg1.reset_index()

# %%
h_neg1 = melt_neg1.pivot(index = 'variable', columns='Series_Name', values='value')
h_neg1.plot(kind='line',figsize=(10,5))
ax = plt.subplot(111)
ax.set_xlabel('Year')
#ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#ax.axvline(x=14, color='grey',ls='--') #2015=20, 2010=15
#ax.axvline(x=19, color='grey',ls='--')
ax.legend(fontsize=12)
plt.savefig('C:/Users/m218101/Desktop/WBS_Coding_school/Course/Final_project/intern_tourism_demographics/pb_s_neg_china_1.png',dpi=200
           ,bbox_inches='tight')
